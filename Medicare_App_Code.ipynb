# %%
# !pip install --force-reinstall numpy==1.24.2
# Out:
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 89.3 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.24.2 which is incompatible.
# blosc2 3.3.2 requires numpy>=1.26, but you have numpy 1.24.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.2 which is incompatible.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.24.2 which is incompatible.
# pymc 5.22.0 requires numpy>=1.25.0, but you have numpy 1.24.2 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.2 which is incompatible.
# albumentations 2.0.6 requires numpy>=1.24.4, but you have numpy 1.24.2 which is incompatible.
# Successfully installed numpy-1.24.2

# %%
# !pip install -qU langchain-community==0.3.14 \
                 langchain-openai==0.2.14 \
                 unstructured==0.16.12 \
                 langgraph==0.2.61 \
                 langchain-qdrant==0.2.0 \
                 ragas==0.2.10 \
                 pymupdf \
                 cohere \
                 langchain_cohere \
                 langchain_huggingface \
                 langchain_core>=0.3.34 \
                 langchain>=0.3.18 \
                 langchain-text-splitters>=0.3.6 \
                 datasets>=3.2.0 \
                 sentence_transformers \
                 pyarrow

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import getpass
import os
from google.colab import userdata

# OPENAI KEY
# Try to get API key from Colab secrets
api_key = userdata.get("OPENAI_API_KEY")
# If not found, prompt the user
if not api_key:
    api_key = getpass.getpass("Enter your OpenAI API key: ")
# Set it as an environment variable
os.environ["OPENAI_API_KEY"] = api_key

# QDRANT KEY
qdrnt_api_key = userdata.get("QDRNT_API_KEY")
if not qdrnt_api_key:
    qdrnt_api_key = getpass.getpass("Enter your QDRNT API key: ")
os.environ["QDRNT_API_KEY"] = qdrnt_api_key

# REDDIT KEYS
reddit_clt_id = userdata.get("reddit_clt_id")
if not reddit_clt_id:
    reddit_clt_id = getpass.getpass("Enter your reddit client id: ")
    os.environ["reddit_clt_id"] = reddit_clt_id

reddit_clt_sec = userdata.get("reddit_clt_secret")
if not reddit_clt_sec:
    reddit_clt_sec = getpass.getpass("Enter your reddit client secret: ")
    os.environ["reddit_clt_sec"] = reddit_clt_sec

# TAVILY API KEY
tavily_api_key = userdata.get("TAVILY_API_KEY")
if not tavily_api_key:
    tavily_api_key = getpass.getpass("Enter your TAVILY API key: ")
os.environ["TAVILY_API_KEY"] = tavily_api_key

#LANGCHAIN
langchain_api_key = userdata.get("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
if not langchain_api_key:
    langchain_api_key = getpass.getpass("Enter your LANGCHAIN API key: ")
os.environ["LANGCHAIN_API_KEY"] = langchain_api_key

#COHERE
cohere_api_key = userdata.get("COHERE_API_KEY")
if not cohere_api_key:
    cohere_api_key = getpass.getpass("Enter your COHERE API key: ")
os.environ["COHERE_API_KEY"] = cohere_api_key

# %%
from uuid import uuid4

os.environ["LANGCHAIN_PROJECT"] = f"AIM - SDG - {uuid4().hex[0:8]}"

# %%
# # 1. Mount your Google Drive
# # from google.colab import drive
# # drive.mount('/content/drive')

# # 2. Ensure the target folder exists
# import os
# drive_folder = '/content/drive/MyDrive/MedicarePilot/pdf_files'
# os.makedirs(drive_folder, exist_ok=True)

# # 3. Download the PDF and save it
# import requests

# url = "https://www.medicare.gov/publications/10050-medicare-and-you.pdf"
# r = requests.get(url, stream=True)
# r.raise_for_status()

# output_path = os.path.join(drive_folder, "10050-medicare-and-you.pdf")
# with open(output_path, "wb") as f:
#     for chunk in r.iter_content(chunk_size=8192):
#         f.write(chunk)

# print(f"✅ PDF saved to: {output_path}")

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-nano"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

# %%
import os
from pathlib import Path
from tqdm.notebook import tqdm

from langchain_community.document_loaders import PyMuPDFLoader
from langchain.schema import Document

PDF_ROOT = Path("/content/drive/MyDrive/MedicarePilot/pdf_files")

pdf_paths = list(PDF_ROOT.rglob("*.pdf"))

# Load PDFs into Documents
pdf_docs = []
errors = []

for pdf_path in tqdm(pdf_paths, desc="Loading PDFs"):
    try:
        loader = PyMuPDFLoader(str(pdf_path))
        # load() returns a list of Document, one per page by default
        page_docs = loader.load()
        # enrich metadata with filename
        for doc in page_docs:
            # ensure metadata has source and page info
            meta = dict(doc.metadata)
            meta["source"] = str(pdf_path)
            # if loader provides 'page' or 'page_number', keep it; otherwise derive
            if "page" not in meta:
                # infer page index from doc.content order
                # PyMuPDFLoader sets metadata["page"] for each Document
                pass
            doc.metadata = meta  # type: ignore
        pdf_docs.extend(page_docs)
        print(f"  ✅ Loaded {len(page_docs)} pages from {pdf_path.name}")
    except Exception as e:
        errors.append((pdf_path.name, str(e)))
        print(f"  ⚠️  Failed to load {pdf_path.name}: {e}")
# Out:
# Loading PDFs:   0%|          | 0/1 [00:00<?, ?it/s]
#   ✅ Loaded 128 pages from 10050-medicare-and-you.pdf
# /usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/parsers/pdf.py:322: UserWarning: Warning: Empty content on page 126 of document /content/drive/MyDrive/MedicarePilot/pdf_files/10050-medicare-and-you.pdf
#   warnings.warn(

# %%
from ragas.testset import TestsetGenerator # Import TestsetGenerator from ragas.testset
import random

# pick 10 random documents (or whatever number you like)
sampled_docs = random.sample(pdf_docs, k=25)

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)

# now generate exactly 15 Q-A pairs from those
dataset = generator.generate_with_langchain_docs(
    sampled_docs,
    testset_size=15
)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/18 [00:00<?, ?it/s]
# Applying HeadlineSplitter:   0%|          | 0/25 [00:00<?, ?it/s]
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# Applying SummaryExtractor:   0%|          | 0/36 [00:00<?, ?it/s]
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '199cd1'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'cfac49'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'd1e6a9'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '4a97f2'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '0116f5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '2ead05'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '3e8ece'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'fcaf89'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '5b9785'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'a6f29a'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '59778a'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '4119d4'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'f451fa'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '21670e'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '4c9377'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '065c7e'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'b91bbf'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '1a30e3'. Skipping!
# Applying CustomNodeFilter: 0it [00:00, ?it/s]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/36 [00:00<?, ?it/s]
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '59778a'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'cfac49'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '0116f5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '199cd1'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'd1e6a9'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '3e8ece'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '2ead05'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '4a97f2'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'f451fa'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '5b9785'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'a6f29a'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'fcaf89'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '065c7e'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '4119d4'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '4c9377'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'b91bbf'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '21670e'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '1a30e3'. Skipping!
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
df = dataset.to_pandas()

# Example path to save the file
output_path = '/content/drive/MyDrive/SDG.csv'

# Assuming your DataFrame is called `df`
df.to_csv(output_path, index=False)
print(f"✅ DataFrame saved to: {output_path}")
# Out:
# ✅ DataFrame saved to: /content/drive/MyDrive/SDG.csv

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0                          Wha is the medicare plan?
# 1              Whre can I get mor info abut Medigap?
# 2  How do I get new Medicare card if lost or dama...
# 3  What does Medicare cover for outpatient hospit...
# 4  How does my other insurance work with Medicare...
# 5  How can I find helpful contacts and informatio...
# 6                         Original Medicare it good?
# 7  How do I get new Medicare card if lost or dama...
#
#                                   reference_contexts  \
# 0  [6\nIndex of topics\n Note: The bold page numb...
# 1  [78\nSection 5: Medicare Supplement Insurance ...
# 2  [108 Section 9: Find helpful contacts and more...
# 3  [48\nSection 2: Find out what Medicare covers\...
# 4  [21\nSection 1: Signing up for Medicare\n21\nH...
# 5  [111\nSection 9: Find helpful contacts and mor...
# 6  [57\n57\n Note: Go to pages 119–122 for defini...
# 7  [108 Section 9: Find helpful contacts and more...
#
#                                            reference  \
# 0  The context does not provide a specific defini...
# 1  You can call your State Insurance Department o...
# 2  If you need a new copy of your Medicare card b...
# 3  Medicare covers many diagnostic and treatment ...
# 4  When you have other insurance like group healt...
# 5  Medicare allows your health care provider’s AC...
# 6  Original Medicare is one of your Medicare heal...
# 7  If you need a new copy of your Medicare card b...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  single_hop_specifc_query_synthesizer
# 4  single_hop_specifc_query_synthesizer
# 5  single_hop_specifc_query_synthesizer
# 6  single_hop_specifc_query_synthesizer
# 7  single_hop_specifc_query_synthesizer

# %% [markdown]
# # RAG

# %%
import tiktoken

from langchain.text_splitter import RecursiveCharacterTextSplitter

def tiktoken_len(text):
    tokens = tiktoken.encoding_for_model("gpt-4o-mini").encode(
        text,
    )
    return len(tokens)

# %%
text_splitter1 = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    length_function = tiktoken_len,
)

text_splitter2 = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 100,
    length_function = tiktoken_len,
)

# %%
split_chunks1 = text_splitter1.split_documents(pdf_docs)
split_chunks2 = text_splitter2.split_documents(pdf_docs)

# %%
len(split_chunks1)
# Out:
# 222

# %%
len(split_chunks2)
# Out:
# 128

# %%
from langchain_openai import OpenAIEmbeddings

embeddings1 = OpenAIEmbeddings(model="text-embedding-3-small")

embeddings2 = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

client1 = QdrantClient(":memory:")

client1.create_collection(
    collection_name="medicare_signup1",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vector_store1 = QdrantVectorStore(
    client=client1,
    collection_name="medicare_signup1",
    embedding=embeddings1,
)

### Larger model

client2 = QdrantClient(":memory:")

client2.create_collection(
    collection_name="medicare_signup2",
    vectors_config=VectorParams(size=3072, distance=Distance.COSINE),
)



vector_store2 = QdrantVectorStore(
    client=client2,
    collection_name="medicare_signup2",
    embedding=embeddings2,
)

# %%
# _ = vector_store.add_documents(documents=split_chunks1)

# %%
_ = vector_store1.add_documents(documents=split_chunks2)

# %%
_ = vector_store2.add_documents(documents=split_chunks2)

# %%
retriever1 = vector_store1.as_retriever(search_kwargs={"k": 5})

# %%
retriever2 = vector_store2.as_retriever(search_kwargs={"k": 5})

# %%
def retrieve1(state):
  retrieved_docs = retriever1.invoke(state["question"])
  return {"context" : retrieved_docs}

# %%
def retrieve2(state):
  retrieved_docs = retriever2.invoke(state["question"])
  return {"context" : retrieved_docs}

# %%
from langchain.prompts import ChatPromptTemplate

RAG_PROMPT = """\
You are a seasoned health insurance advisor with over 30 years in the industry.
You have tremendous knowledge about the industry and the different players.
You keep track of the changes in regulations and you are here to advise the user with their questions or concerns.
If there are any industry jargons in your responses make them easy to understand and provide details of what they are.
Wherever available provide references.
If you are unable to get the answer from the context provided, just say that you don't know. Don't try to make up an answer.

### Question
{question}

### Context
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_PROMPT)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
def generate(state):
  docs_content = "\n\n".join(doc.page_content for doc in state["context"])
  messages = rag_prompt.format_messages(question=state["question"], context=docs_content)
  response = llm.invoke(messages)
  return {"response" : response.content}

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
from langchain_core.documents import Document

class State(TypedDict):
  question: str
  context: List[Document]
  response: str

# %%
graph_builder1 = StateGraph(State).add_sequence([retrieve1, generate])
graph_builder1.add_edge(START, "retrieve1")
graph1 = graph_builder1.compile()

graph_builder2 = StateGraph(State).add_sequence([retrieve2, generate])
graph_builder2.add_edge(START, "retrieve2")
graph2 = graph_builder2.compile()

# %%
response1 = graph1.invoke({"question" : "How are LLM agents useful?"})
print(response1['response'])
# Out:
# I'm sorry, but I don't know how LLM agents are useful in the context of health insurance or related topics. If you have any questions specific to health insurance or Medicare, feel free to ask!

# %%
response1 = graph1.invoke({"question" : "How much would a stay in a long term care?"})
print(response1['response'])
# Out:
# The cost of a long-term care stay can vary widely depending on several factors, including the type of facility, geographic location, and the level of care required. Here are some general estimates based on common types of long-term care:
#
# 1. **Assisted Living Facilities**: The average monthly cost for assisted living in the United States can range from $3,000 to $5,000, depending on the location and services offered.
#
# 2. **Nursing Homes**: For nursing homes, the average daily cost can range from $200 to $400 or more, translating to approximately $6,000 to $12,000 per month. Costs may be higher for private rooms compared to semi-private rooms.
#
# 3. **Home Care Services**: If care is provided at home, costs typically range from $20 to $50 per hour for home health aides, leading to a monthly cost that can vary widely based on the number of hours of care needed.
#
# It's important to note that Medicare does not cover non-medical long-term care services, such as assistance with daily activities (like bathing, dressing, and using the bathroom). It may cover certain medical services or care in a skilled nursing facility after a qualifying hospital stay, but only for a limited duration.
#
# For more detailed information on costs in your specific area, you may want to consult resources such as the Genworth Cost of Care Survey, which provides comprehensive data on long-term care costs across the United States.
#
# If you're considering long-term care options, it's advisable to start planning early and explore all available resources, including Medicaid, private long-term care insurance, or state assistance programs.

# %%
response2 = graph2.invoke({"question" : "How much would a stay in a long term care?"})
print(response2['response'])
# Out:
# The cost of a long-term care stay can vary significantly based on various factors, including the type of facility, the level of care required, and the geographical location. Unfortunately, the provided context does not specify the costs associated with long-term care stays directly.
#
# However, I can provide some general information:
#
# 1. **Types of Long-Term Care Facilities**:
#    - **Nursing Homes**: These facilities provide 24-hour medical care. Costs can range from $7,000 to over $10,000 per month, depending on location and services offered.
#    - **Assisted Living Facilities**: These provide a combination of housing and personal care services. Monthly costs can range from $3,000 to $7,000.
#    - **In-Home Care**: Hiring a caregiver to assist at home can cost between $20 to $50 per hour, depending on the level of care needed.
#
# 2. **Medicare Coverage**:
#    - Medicare typically does not cover long-term care. While it may cover short-term stays in skilled nursing facilities (usually after a hospital stay), it only covers a limited number of days and specific types of care.
#
# 3. **Out-of-Pocket Costs**:
#    - For skilled nursing facility care, Medicare covers costs for days 1-20 at 100%, then there is a daily copayment for days 21-100. After day 100, you would be responsible for all costs.
#
# 4. **Financial Assistance**:
#    - Medicaid may cover long-term care for those who qualify based on income and assets, but eligibility varies by state.
#
# For the most accurate and personalized information, I recommend contacting local facilities or a financial advisor who specializes in long-term care planning. They can provide specific pricing and options based on your needs and situation. If you have any other questions or need further clarification, feel free to ask!

# %%
response1 = graph1.invoke({"question" : "Does Medicare pay for long term care stay?"})
print(response1['response'])

# %%
for test_row in dataset:
  response1 = graph1.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response1["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response1["context"]]

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0                          Wha is the medicare plan?
# 1              Whre can I get mor info abut Medigap?
# 2  How do I get new Medicare card if lost or dama...
# 3  What does Medicare cover for outpatient hospit...
# 4  How does my other insurance work with Medicare...
# 5  How can I find helpful contacts and informatio...
# 6                         Original Medicare it good?
# 7  How do I get new Medicare card if lost or dama...
#
#                                   retrieved_contexts  \
# 0  [121\n121\nSection 10: Definitions\n121\nMedic...
# 1  [78\nSection 5: Medicare Supplement Insurance ...
# 2  [108 Section 9: Find helpful contacts and more...
# 3  [48\nSection 2: Find out what Medicare covers\...
# 4  [21\nSection 1: Signing up for Medicare\n21\nH...
# 5  [111\nSection 9: Find helpful contacts and mor...
# 6  [57\n57\n Note: Go to pages 119–122 for defini...
# 7  [108 Section 9: Find helpful contacts and more...
#
#                                   reference_contexts  \
# 0  [6\nIndex of topics\n Note: The bold page numb...
# 1  [78\nSection 5: Medicare Supplement Insurance ...
# 2  [108 Section 9: Find helpful contacts and more...
# 3  [48\nSection 2: Find out what Medicare covers\...
# 4  [21\nSection 1: Signing up for Medicare\n21\nH...
# 5  [111\nSection 9: Find helpful contacts and mor...
# 6  [57\n57\n Note: Go to pages 119–122 for defini...
# 7  [108 Section 9: Find helpful contacts and more...
#
#                                             response  \
# 0  Medicare is a federal health insurance program...
# 1  You can find more information about Medigap (M...
# 2  If you've lost or damaged your Medicare card, ...
# 3  Medicare covers a variety of outpatient hospit...
# 4  When you have other insurance in addition to M...
# 5  To find helpful contacts and information about...
# 6  Original Medicare can be a good option for man...
# 7  If you've lost or damaged your Medicare card, ...
#
#                                            reference  \
# 0  The context does not provide a specific defini...
# 1  You can call your State Insurance Department o...
# 2  If you need a new copy of your Medicare card b...
# 3  Medicare covers many diagnostic and treatment ...
# 4  When you have other insurance like group healt...
# 5  Medicare allows your health care provider’s AC...
# 6  Original Medicare is one of your Medicare heal...
# 7  If you need a new copy of your Medicare card b...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  single_hop_specifc_query_synthesizer
# 4  single_hop_specifc_query_synthesizer
# 5  single_hop_specifc_query_synthesizer
# 6  single_hop_specifc_query_synthesizer
# 7  single_hop_specifc_query_synthesizer

# %%
from ragas import EvaluationDataset

evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

# %%
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper

evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o"))

# %%
#Chunk size - 500 tokens
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result1 = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result1
# Out:
# Evaluating:   0%|          | 0/48 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[22]: LLMDidNotFinishException(The LLM generation was not completed. Please increase try increasing the max_tokens and try again.)
# ERROR:ragas.executor:Exception raised in Job[41]: TimeoutError()
# {'context_recall': 1.0000, 'faithfulness': 0.8177, 'factual_correctness': 0.5550, 'answer_relevancy': 0.8308, 'context_entity_recall': 0.4384, 'noise_sensitivity_relevant': 0.3790}

# %%
#Chunk size - 1000 tokens
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result2 = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result2
# Out:
# Evaluating:   0%|          | 0/48 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[22]: LLMDidNotFinishException(The LLM generation was not completed. Please increase try increasing the max_tokens and try again.)
# {'context_recall': 1.0000, 'faithfulness': 0.8279, 'factual_correctness': 0.5588, 'answer_relevancy': 0.8282, 'context_entity_recall': 0.4241, 'noise_sensitivity_relevant': 0.3660}

# %%
print(result1)
# Out:
# {'context_recall': 0.4000, 'faithfulness': 0.8529, 'factual_correctness': 0.2840, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.2783, 'noise_sensitivity_relevant': 0.4429}

# %%
print(result2)
# Out:
# {'context_recall': 0.4000, 'faithfulness': 0.8315, 'factual_correctness': 0.2760, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.3059, 'noise_sensitivity_relevant': 0.3962}

# %% [markdown]
# # Using Cohere

# %%
retriever = vector_store2.as_retriever(search_kwargs={"k": 20})

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

def retrieve_adjusted(state):
  compressor = CohereRerank(model="rerank-v3.5")
  compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever, search_kwargs={"k": 5}
  )
  retrieved_docs = compression_retriever.invoke(state["question"])
  return {"context" : retrieved_docs}

# %%
class State(TypedDict):
  question: str
  context: List[Document]
  response: str

graph_builder = StateGraph(State).add_sequence([retrieve_adjusted, generate])
graph_builder.add_edge(START, "retrieve_adjusted")
graph = graph_builder.compile()

# %%
response = graph.invoke({"question" : "Does Medicare pay for long term care stay?"})
response["response"]
# Out:
# "Medicare does not pay for long-term care stays that are considered non-medical. This includes personal care assistance, which involves help with daily activities such as dressing, bathing, and using the bathroom, as well as services like home-delivered meals or adult day health care. \n\nWhile Medicare may cover skilled nursing facility care, this is only under specific conditions: you must have a medically necessary inpatient hospital stay of at least three days, and the care you receive at the skilled nursing facility must be for a condition related to that hospital stay. The care must also be skilled care, which means it requires the services of licensed professionals, such as nurses or therapists.\n\nFor long-term care needs that are not covered by Medicare, you might want to consider Medicaid or private long-term care insurance options. Medicaid can cover some long-term care services, but eligibility varies by state, so it's essential to check your local Medicaid office for specifics.\n\nFor further information about long-term care and its coverage, you can visit resources like ACL.gov/ltc or contact your State Medical Assistance (Medicaid) office."

# %%
import time

for test_row in dataset:
  response = graph.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]
  time.sleep(2) # To try to avoid rate limiting.

# %%
result3 = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result3
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[16]: LLMDidNotFinishException(The LLM generation was not completed. Please increase try increasing the max_tokens and try again.)
# {'context_recall': 0.4000, 'faithfulness': 0.8561, 'factual_correctness': 0.2620, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.2831, 'noise_sensitivity_relevant': 0.3742}

# %%
print(result3)
# Out:
# {'context_recall': 0.4000, 'faithfulness': 0.8561, 'factual_correctness': 0.2620, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.2831, 'noise_sensitivity_relevant': 0.3742}

# %%
print(result1)
# Out:
# {'context_recall': 0.4000, 'faithfulness': 0.8529, 'factual_correctness': 0.2840, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.2783, 'noise_sensitivity_relevant': 0.4429}

# %%
print(result2)
# Out:
# {'context_recall': 0.4000, 'faithfulness': 0.8315, 'factual_correctness': 0.2760, 'answer_relevancy': 0.9474, 'context_entity_recall': 0.3059, 'noise_sensitivity_relevant': 0.3962}

# %% [markdown]
# Cohere is not any better than Large embedding but is slightly better than the openai small embedding

# %% [markdown]
# # Fine tuned embedding model

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings4 = HuggingFaceEmbeddings(model_name="vivnatan/snowflake-arctic-embed-l-medicare")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1966         try:
# -> 1967             return importlib.import_module("." + module_name, self.__name__)
#    1968         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in <module>
#      68 )
# ---> 69 from .loss.loss_utils import LOSS_MAPPING
#      70 from .pytorch_utils import (  # noqa: F401
#
# /usr/local/lib/python3.11/dist-packages/transformers/loss/loss_utils.py in <module>
#      20
# ---> 21 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      22 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# /usr/local/lib/python3.11/dist-packages/transformers/loss/loss_deformable_detr.py in <module>
#       3
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# /usr/local/lib/python3.11/dist-packages/transformers/image_transforms.py in <module>
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      48
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
#       7
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/__init__.py in <module>
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py in <module>
#       7
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/compat/v1/__init__.py in <module>
#      46 from tensorflow._api.v2.compat.v1 import linalg
# ---> 47 from tensorflow._api.v2.compat.v1 import lite
#      48 from tensorflow._api.v2.compat.v1 import logging
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/lite/__init__.py in <module>
#       8 from tensorflow._api.v2.compat.v1.lite import constants
# ----> 9 from tensorflow._api.v2.compat.v1.lite import experimental
#      10 from tensorflow.lite.python.convert import OpsSet # line: 170
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/__init__.py in <module>
#       7
# ----> 8 from tensorflow._api.v2.compat.v1.lite.experimental import authoring
#       9 from tensorflow.lite.python.analyzer import ModelAnalyzer as Analyzer # line: 35
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/authoring/__init__.py in <module>
#       7
# ----> 8 from tensorflow.lite.python.authoring.authoring import compatible # line: 263
#       9
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/authoring/authoring.py in <module>
#      41 # pylint: disable=g-import-not-at-top
# ---> 42 from tensorflow.lite.python import convert
#      43 from tensorflow.lite.python import lite
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py in <module>
#      34 from tensorflow.lite.python import lite_constants
# ---> 35 from tensorflow.lite.python import util
#      36 from tensorflow.lite.python.convert_phase import Component
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/util.py in <module>
#      52 try:
# ---> 53   from jax import jit as _jit
#      54 except ImportError:
#
# /usr/local/lib/python3.11/dist-packages/jax/__init__.py in <module>
#      36 # Force early import, allowing use of `jax.core` after importing `jax`.
# ---> 37 import jax.core as _core
#      38 del _core
#
# /usr/local/lib/python3.11/dist-packages/jax/core.py in <module>
#      17
# ---> 18 from jax._src.core import (
#      19   AbstractToken as AbstractToken,
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/core.py in <module>
#      36
# ---> 37 from jax._src import dtypes
#      38 from jax._src import config
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/dtypes.py in <module>
#     520 _string_types: list[JAXType] = []
# --> 521 if hasattr(np.dtypes, 'StringDType') and xla_extension_version >= 311:
#     522   _string_types: list[JAXType] = [np.dtypes.StringDType()]  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     319
# --> 320         raise AttributeError("module {!r} has no attribute "
#     321                              "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'dtypes'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-48-af3f65afd96f> in <cell line: 0>()
#       1 from langchain_huggingface import HuggingFaceEmbeddings
#       2
# ----> 3 embeddings4 = HuggingFaceEmbeddings(model_name="vivnatan/snowflake-arctic-embed-l-medicare")
#
# /usr/local/lib/python3.11/dist-packages/langchain_huggingface/embeddings/huggingface.py in __init__(self, **kwargs)
#      64         super().__init__(**kwargs)
#      65         try:
# ---> 66             import sentence_transformers  # type: ignore[import]
#      67         except ImportError as exc:
#      68             raise ImportError(
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/__init__.py in <module>
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/__init__.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in <module>
#      17 from torch import nn
#      18 from tqdm.autonotebook import trange
# ---> 19 from transformers import (
#      20     AutoConfig,
#      21     AutoModelForSequenceClassification,
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1953             value = Placeholder
#    1954         elif name in self._class_to_module.keys():
# -> 1955             module = self._get_module(self._class_to_module[name])
#    1956             value = getattr(module, name)
#    1957         elif name in self._modules:
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1967             return importlib.import_module("." + module_name, self.__name__)
#    1968         except Exception as e:
# -> 1969             raise RuntimeError(
#    1970                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1971                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# module 'numpy' has no attribute 'dtypes'

# %%
### Larger model

client4 = QdrantClient(":memory:")

client4.create_collection(
    collection_name="medicare_signup4",
    vectors_config=VectorParams(size=1024, distance=Distance.COSINE),
)



vector_store4 = QdrantVectorStore(
    client=client4,
    collection_name="medicare_signup4",
    embedding=embeddings4,
)

# %%
_ = vector_store4.add_documents(documents=split_chunks2)

# %%
retriever4 = vector_store4.as_retriever(search_kwargs={"k": 5})

# %%
def retrieve4(state):
  retrieved_docs = retriever4.invoke(state["question"])
  return {"context" : retrieved_docs}

# %%
graph_builder4 = StateGraph(State).add_sequence([retrieve4, generate])
graph_builder4.add_edge(START, "retrieve4")
graph2 = graph_builder4.compile()

# %%
#Chunk size - 1000 tokens
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result4 = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result4

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import BSHTMLLoader

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap  = 25,
    length_function = tiktoken_len
)

# %%
training_documents = split_chunks1
# text_splitter.split_documents(text_loader.load())

# %%
len(training_documents)
# Out:
# 222

# %%
import uuid

id_set = set()

for document in training_documents:
  id = str(uuid.uuid4())
  while id in id_set:
    id = uuid.uuid4()
  id_set.add(id)
  document.metadata["id"] = id

# %%
training_split_documents = training_documents[:len(training_documents) - 40]
val_split_documents = training_documents[len(training_documents) - 40:len(training_documents)-20]
test_split_documents = training_documents[len(training_documents)-20:]

# %%
len(training_split_documents), len(val_split_documents), len(test_split_documents)
# Out:
# (182, 20, 20)

# %%
from langchain_openai import ChatOpenAI

qa_chat_model = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0
)

# %%
from langchain_core.prompts import ChatPromptTemplate

qa_prompt = """\
Given the following context, you must generate questions based on only the provided context.

You are to generate {n_questions} questions which should be provided in the following format:

1. QUESTION #1
2. QUESTION #2
...

Context:
{context}
"""

qa_prompt_template = ChatPromptTemplate.from_template(qa_prompt)

# %%
question_generation_chain = qa_prompt_template | qa_chat_model

# %%
import tqdm
import asyncio

"""
Sample Usage of TQDM:

for i in tqdm.tqdm(range(10)):
  time.sleep(1)
"""

async def process_document(document, n_questions):
    questions_generated = await question_generation_chain.ainvoke({"context": document.page_content, "n_questions": n_questions})

    doc_questions = {}
    doc_relevant_docs = {}

    for question in questions_generated.content.split("\n"):
        question_id = str(uuid.uuid4())
        doc_questions[question_id] = "".join(question.split(".")[1:]).strip()
        doc_relevant_docs[question_id] = [document.metadata["id"]]

    return doc_questions, doc_relevant_docs

async def create_questions(documents, n_questions):
    tasks = [process_document(doc, n_questions) for doc in documents]

    questions = {}
    relevant_docs = {}

    for task in tqdm.tqdm(asyncio.as_completed(tasks), total=len(documents), desc="Processing documents"):
        doc_questions, doc_relevant_docs = await task
        questions.update(doc_questions)
        relevant_docs.update(doc_relevant_docs)

    return questions, relevant_docs

# %%
training_questions, training_relevant_contexts = await create_questions(training_split_documents, 5)
# Out:
# Processing documents: 100%|██████████| 182/182 [00:12<00:00, 14.42it/s]

# %%
training_questions
# Out:
# {'6db26c7a-a30f-4caa-b184-1c770ff8cf90': 'How can you safely store and discard unused prescription opioids?',
#  '2e7e476f-8824-4baf-abbe-896374e0fdb2': 'Where can you find more information on safe and effective pain management and opioid use?',
#  'e9a8ef9e-311e-4d57-bc03-12bed772df5e': 'Do Medicare drug plans offer automatic prescription refills by mail?',
#  'f7eb3b27-4e7d-4ddf-b4e9-da12f4841c96': 'What pages cover information about Advance Beneficiary Notice of Non-coverage (ABN)?',
#  '51147819-40b9-47ef-9bf6-c8db1de72d2e': 'On which pages can you find details about Behavioral health integration services?',
#  'a0c42bdf-a94f-4160-9c35-7de75bb19ad2': 'Where in the document is the topic of Appeals discussed?',
#  'a14e61ea-dc4d-4c67-a2de-c2e48908dcd2': 'What are the costs associated with the immunosuppressive drug benefit under Medicare in 2025?',
#  '98116705-097d-4d1f-9d18-cb1295414de8': 'Under what conditions does Medicare cover health care services while traveling outside the US?',
#  '4bf7d143-a0a7-47f0-95a0-a29d7cd58b1d': 'How does Medicare cover virtual check-ins with health care providers?',
#  'a691f8af-f227-460d-829d-04eac8986fba': 'How many times can you switch Medicare plans during the specified period?',
#  '6ac1ed69-d128-4794-8c24-51cc6367991f': 'What is the purpose of the Medicare star ratings from 1 to 5?',
#  '7c87b4d4-f24b-4440-9387-e9f7d183400d': 'What special enrollment opportunity is available if a 5-star Medicare plan is offered in your area?',
#  '8b64ada7-de49-45a8-8197-c3a320115e9f': 'What are some risk factors that may put you at medium or high risk for Hepatitis B?',
#  '0982291c-3815-4102-abd6-0a38c583d738': 'Under what conditions does Medicare cover Hepatitis B Virus infection screening tests?',
#  '30851ad0-8af3-4ac3-b12e-cc5d385d9773': 'When do you pay nothing for the Hepatitis B shot according to the provided context?',
#  'f46c10c1-ea7f-4000-80d1-e78de3c01530': 'What topics are covered under Part B (Medical Insurance) according to the index?',
#  '86292e38-433a-41b3-aa8c-cd7fd1f99278': 'Which pages provide detailed information about the Program of All-inclusive Care for the Elderly (PACE)?',
#  'a46a2522-15b9-444a-aeaf-2e931026204f': 'Where can information about Pneumococcal shots be found in the document?',
#  '2483c5f8-2024-4841-975b-d0549ed96440': 'How can you get help with Medicare costs according to the context?',
#  'bc65960f-89a0-48ac-8f32-b4e7c0dade83': 'What happens to your Part B premium if you receive Social Security or Railroad Retirement Board benefits?',
#  '3f742d3a-30bd-4a70-a9eb-59e975d9b340': 'Where should you mail your Part B premium payments if you receive a bill from the Railroad Retirement Board?',
#  '1b7c1faf-85de-4085-89d8-08b70548d056': 'What are some of the additional safety checks included in opioid safety protocols?',
#  'eb2c6106-1970-4a2b-a4da-d9ec822bd960': 'Why is it risky to take opioids at the same time as benzodiazepines or certain other medications?',
#  '63920f36-ba86-487f-a51f-cd817ea90ef8': 'How do Medicare drug management programs help ensure the safe use of opioids and benzodiazepines?',
#  '127b41df-9034-4863-8728-2b8a8104536d': 'What types of chronic conditions can membership in a Special Needs Plan (SNP) be limited to?',
#  '42f3f465-df00-421f-a8ce-f1a91933edeb': 'Who is eligible to join an Institutional SNP (I-SNP)?',
#  '2cb559a9-86cd-4e3c-8b63-1030d37193d7': 'How often can someone with Medicare and full Medicaid benefits join or switch an integrated D-SNP?',
#  '9cf0fc26-c957-4c9c-9a79-087a6fb13ccf': 'What is the title of the official US government Medicare handbook for 2025?',
#  'd9608413-e4fa-4103-b42d-2bfb4e742424': 'Which government program is the focus of the "Medicare & You 2025" handbook?',
#  '4ce479db-2747-4760-8f3f-cdc4a4cc3190': 'For which year is the "Medicare & You" handbook intended?',
#  '16d36cd1-5bc2-4839-9161-e0c9223057e9': 'What types of communication technology can be used for virtual check-ins covered by Medicare?',
#  '27524a29-5d97-482f-82c7-4f183c48060e': 'What are the conditions that must be met for a patient to have a virtual check-in?',
#  '6b2a2b60-4488-484e-a2af-22f9edd09e83': 'How do virtual check-ins differ from telehealth visits in terms of duration and real-time interaction?',
#  '6e3b777b-3df8-4337-893f-6173f7f2a3aa': 'What actions will your Medicare plan take if it determines that your use of prescription opioids and benzodiazepines may not be safe?',
#  '88ada05c-e6c9-4a6e-9480-6f11f888694e': 'Under what circumstances do opioid safety reviews and Drug Management Programs generally not apply?',
#  '812a929c-4410-4699-9495-336df34806e3': 'What are some important tips Medicare provides for individuals who are prescribed opioids?',
#  'eeeec386-99e5-444e-8afb-fe197e38cccf': 'When do you need to sign up for Medicare Part A and Part B if you are close to 65 but not receiving Social Security or RRB benefits?',
#  '6095cb61-b0a4-4bff-8d63-e531c3fbd736': 'Where can you apply for Medicare Part A and Part B online?',
#  '1515e31c-680b-41c6-8637-011f621a7a8e': 'What are the consequences of not signing up for Medicare Part B when you are first eligible?',
#  'b663e720-dd77-4f7c-800f-a2f604b7ef79': 'What are the cost-sharing requirements for Medicare coverage of implantable cardioverter defibrillators in outpatient settings?',
#  'af77c7a4-b501-4657-ae75-8e6ef14ec80a': 'How often does Medicare cover depression screening, and what conditions must be met for the screening to be free?',
#  'ce6b64c3-afab-47fe-8661-b145ff6a1658': 'What diabetes-related equipment and supplies does Medicare cover, and what are the associated costs for beneficiaries?',
#  '5bd91040-c156-4fa0-968a-998d61dd2891': 'What changes can you make to your Medicare Advantage Plan during the Medicare Advantage Open Enrollment Period from January 1 to March 31?',
#  '63c87f40-68dd-480f-bd74-08f370da1fb6': '',
#  'ba308589-8b87-4fec-8810-b3794754078a': 'During the Medicare Advantage Open Enrollment Period, what actions are you not allowed to take if you have Original Medicare?',
#  '8022f92a-77d8-4d77-b9e1-79fccfd47543': '',
#  'a772ce53-165f-4092-a2fa-aca1bfe6de54': 'What is the 5-star Special Enrollment Period, and how does it relate to switching Medicare Advantage Plans?',
#  '15d83664-b829-48c6-8243-57c60402283a': 'What types of heart-related procedures and conditions does Medicare cover under cardiac care?',
#  '4e9a516c-0e86-4b43-b174-871d2d47b833': 'How often does Medicare cover cardiovascular disease screening blood tests, and what costs are involved for the patient?',
#  '9b9eb918-b617-42f4-a9f7-cd8c525d52bf': 'What are the requirements and costs associated with Medicare-covered caregiver training?',
#  '9281c597-48df-42c0-869c-f7b71a571df0': 'How much do you pay for days 1–60 of each benefit period after meeting your Part A deductible in 2025?',
#  '8ac84efd-77e7-411a-8a11-12939031b3d4': 'What is the daily cost for days 61–90 of each benefit period in 2025?',
#  '8f6f5f64-f83a-4157-a2e8-04dfee3d7eb1': 'How many lifetime reserve days are available, and what is the daily cost after day 90 of each benefit period in 2025?',
#  '20df35c6-035e-4abc-897b-704129ddd0b3': 'What are the eligibility criteria for receiving FDA-authorized or approved COVID-19 treatments covered by Medicare?',
#  '4b3b5c02-2ec6-418c-aed8-21b370883577': 'Does Original Medicare cover the cost of monoclonal antibody treatments for COVID-19 symptoms, and are there any out-of-pocket costs?',
#  'ac506b63-9ea0-486d-a602-925e3fd69407': 'Can certain monoclonal antibody products be used to protect against COVID-19 before exposure, and under what conditions does Medicare cover these products?',
#  '868a0802-f234-45d1-95b9-de11079e70c1': 'What are the conditions under which Medicare covers advance care planning without any cost to the patient?',
#  'bfa4f948-8811-4d51-a01c-6fb6866c705d': 'How many alcohol misuse counseling sessions does Medicare cover per year, and where must these sessions take place?',
#  '20394add-c395-42da-8eb7-799d3fff5e09': 'Under what circumstances does Medicare cover ambulance transportation, and what costs are the patient responsible for?',
#  '0e5f0768-5ce0-44b0-bb5a-b8ad8ac56502': 'What services are included in the “Welcome to Medicare” preventive visit during the first 12 months of having Part B?',
#  'e68a8438-273f-4e9e-a343-88502dacf979': 'How much do you pay for the “Welcome to Medicare” preventive visit if the doctor accepts assignment?',
#  '131dd284-4547-41ea-8ffa-8a7761f96a94': 'What is the purpose of the yearly “Wellness” visit after you have had Part B for longer than 12 months?',
#  '6ad600bb-30ed-4f6f-92d2-cfe412f63805': 'What are the two main ways to get Medicare coverage mentioned in the guide?',
#  'd4936d3c-4b1c-4201-9dc8-34d8cd8a8006': 'During which dates in 2025 can someone in a Medicare Advantage Plan switch to a different plan or to Original Medicare?',
#  '8fd11f27-7051-45b1-a400-560f55c54d31': 'When does the Open Enrollment Period for changing Medicare health or drug coverage for 2026 begin and end?',
#  '27d1eed8-188e-4496-88a3-1553d95647fd': 'When can you join a Medicare Advantage Plan during your Initial Enrollment Period?',
#  '5e10d92c-93a0-4fe5-aec7-60369e90486f': 'What are the dates for the General Enrollment Period, and what are the requirements to join a Medicare Advantage Plan during this time?',
#  '4b977819-a077-4923-876f-45dc078fd07b': 'What options do you have during the Open Enrollment Period from October 15 to December 7 regarding Medicare Advantage Plans?',
#  '27903d62-b947-41dd-955a-b6036534f7b3': 'When should you make your last HSA contribution to avoid a tax penalty if your birthday is on the 1st day of the month?',
#  '200343aa-4c69-4704-95cf-faa1c1d5b23f': 'How can you avoid a tax penalty if you sign up for Medicare less than 6 months after you turn 65?',
#  '7f05c442-54aa-416a-9361-ad0fa5a4aa42': 'What is the recommended timing to stop HSA contributions if you apply for Medicare 6 or more months after turning 65?',
#  'c538de8a-24cf-48ee-b0cd-fb45e3e500b7': 'What types of care does Medicare Part A help cover?',
#  '68a56e40-fa79-41b0-8030-f9e758862771': 'Which services are included under Medicare Part B coverage?',
#  '0be77be3-cf28-45bc-b603-ea7cfbb622d8': 'Who runs the plans that offer Medicare Part D drug coverage?',
#  'a6bfc862-7e2e-4cd9-85f1-0f146824f1ea': 'How can federal retirees with an annuity from the Office of Personnel Management have their Part B premiums deducted?',
#  'd607ac3a-d9f2-4ab9-b845-f2a8b06702b3': 'What are the four ways to pay your Medicare Part B premium bill?',
#  '0983e189-561d-4601-bf90-6d4fb116216e': 'What information do you need to provide to your bank to set up a payment for your Medicare premium?',
#  '72c41fd9-64d1-441b-bd7a-44c07ef741d0': 'What are the eligibility requirements to qualify for the Program of All-inclusive Care for the Elderly (PACE)?',
#  '7de88e52-a8f8-4a79-86ca-4296c15ea476': 'What types of care and services does PACE cover for its participants?',
#  '4f9d8494-749f-4df1-9436-1be58f51af80': 'How does the cost structure of PACE differ for individuals with Medicaid compared to those with only Medicare?',
#  '9beba0db-8fc2-4961-9097-a68a5e2b265d': 'What types of financial resources are included when determining income limits?',
#  '7ce925bf-273b-40b4-851a-463b537fc9f0': 'Which items are excluded from the resource calculation according to the context?',
#  '1a9aa46f-c05f-419b-a043-6fbade51a1ab': 'Where can you find the 2025 income and resource limits information?',
#  'f16382e7-0366-4a44-a4d3-cd0474222791': 'What pages provide information about Immunosuppressive drug coverage?',
#  '76261bf0-9e51-4fb7-bd5d-6724dfd95738': 'Where can you find details about the Initial Enrollment Period?',
#  '70e90c3d-72e3-4509-af19-9bf25a98156b': 'On which pages is Long-term care discussed?',
#  'c401aa73-3af1-4390-98f8-03b2021686b6': 'What methods can you use to pay your Medicare premiums through the mail?',
#  'c00e02c4-bd94-417b-a44e-1743eb596799': 'Where should you mail your Medicare payment coupon and payment?',
#  '30e6e883-21fa-40d7-9d46-339269742620': 'If you have questions about your Medicare premiums, what phone number can you call?',
#  'eaf81def-581d-4e56-9e84-681cfb8cd386': 'What page numbers provide detailed information about drug coverage under Supplemental insurance (Medigap)?',
#  'bf820443-bcf1-4782-8436-deb3b072b930': 'Where can you find information about telehealth services in the index?',
#  'a29f59a9-5faf-407c-93dd-44e871794aaa': 'Which pages cover topics related to transplant services?',
#  '05e5292f-543f-4cfa-bc89-0df5b4946aa5': 'What types of durable medical equipment does Medicare cover when ordered by a Medicare-enrolled doctor?',
#  'e933223b-7f55-4eff-a281-4fc53364120d': 'How much do you typically pay for durable medical equipment under Medicare Part B?',
#  '9a72ceb8-5c99-4f27-be10-64657fe957b2': 'Why is it important to confirm that your DME suppliers participate in Medicare before obtaining equipment?',
#  'b1824f77-8441-4b45-877a-dea0a5dc7ff6': 'What types of prosthetic devices are covered by Medicare according to the context?',
#  'c3d89976-17f3-4a9b-9bcc-f01bed0e2019': 'Under what conditions does Medicare cover a comprehensive pulmonary rehabilitation program?',
#  '9abc9165-4831-4fbc-81e9-422f5e666aa8': 'What are the cost-sharing requirements for Medicare beneficiaries receiving prosthetics or pulmonary rehabilitation services?',
#  '0cfcad2f-07ed-4969-9dcd-5a49529c8d23': 'What information does the Evidence of Coverage provide about your plan?',
#  'f8a6baba-fd61-4b9a-93ce-58d3b892df84': 'By what date will your plan send you a printed copy of the Evidence of Coverage?',
#  'd571cd43-e34a-414b-81d4-a5a5286bfbc0': 'Where can you sign up for an electronic version of the “Medicare & You” handbook?',
#  'ff909f5d-de76-47b4-b09b-1145edafc0da': 'What are some of the services that Original Medicare does not cover?',
#  'a9bf70aa-bed0-4876-812c-8983eb54d901': 'Under what conditions might you not have to pay out of pocket for services not covered by Part A or Part B?',
#  'b5548f69-4d07-4dd0-ba8a-677bcf1bf5db': 'What extra benefits might Medicare Advantage Plans and Medicare Cost Plans cover that Original Medicare does not?',
#  '524fafec-11b1-41f6-8178-4677cae47a48': 'How will you be informed each year about whether your drug coverage is creditable?',
#  '2d4c81c9-8661-4f24-ba87-d77d04cf43b9': 'Who should you contact for more information before making changes to your drug coverage?',
#  'fbea3a8d-6b56-459e-8b06-5fbc2c6ff5c4': 'What might happen to your employer or union health coverage if you get Medicare drug coverage?',
#  '62634f38-4ff4-4c6d-b969-c4e6ae9ccf95': 'What are the two parts included in Original Medicare?',
#  'c5f90de8-15f5-4b3f-9092-86a91bfe9ffc': 'Can you use any Medicare-enrolled doctor or hospital with Original Medicare?',
#  'f95dd8eb-9ff9-4336-aab2-dc29315ef8e8': 'Does Medicare Part B cover most prescription drugs?',
#  '4cfb5ea1-e2a6-4126-9947-490f4982e699': 'What costs might you incur if you get a test at a hospital as an outpatient under Medicare Part B?',
#  '9b34c3a7-fb60-4408-8b56-524377e0c547': 'Under what conditions does Medicare cover immunosuppressive drugs after an organ transplant?',
#  '8bfe4661-34b2-4e1a-ab39-392bbef7df13': 'Why is it important to check with a Medicare Advantage Plan if you are on a transplant waiting list or need a transplant?',
#  'dd617718-b37c-4bc2-848d-0890bcfe80a1': 'What topics are covered under the notices section in the provided context?',
#  '74a198b3-c8c2-4b73-91b1-d87e55da2bfa': 'Which pages discuss retiree health insurance coverage according to the context?',
#  '4036fb6c-480c-4f8e-ba99-da04bedef420': 'Where can information about the Medicare Outpatient Observation Notice (MOON) be found?',
#  '070a7297-788c-4ca0-829e-b314371324ad': 'What are the conditions under which Medicare covers a Hepatitis C screening test?',
#  'caebed71-064e-44d7-928a-4241ada133b2': 'How many times does Medicare cover HIV screening tests during a pregnancy?',
#  '5cdac8b8-75f4-47c0-bc09-105807b74e00': 'What types of home health services does Medicare cover under Part A and/or Part B?',
#  '01eb12c9-828c-481a-aa56-682ae991b0a5': 'What foot care services does Medicare cover for individuals with diabetes-related lower leg nerve damage?',
#  '014430a0-2d2f-4c40-8b4a-9d034f8cfa61': 'Under what conditions does Medicare cover glaucoma screenings, and how often are these screenings covered?',
#  '2317f890-b052-4f4f-88c7-da65276e8bba': 'When does Medicare cover hearing and balance exams, and are hearing aids included in this coverage?',
#  'c9671174-4f63-47ea-a0c8-0c1064e193a5': 'Where can you visit online to learn more about planning for long-term care?',
#  '1c6f338d-83e6-4265-b7ac-c5fdc712a11e': 'What phone number can you call to find help in your community through the Eldercare Locator?',
#  '0fb7d42d-dfec-4e46-b40b-b2139df0cd3e': 'How can you obtain a copy of “A Shopper’s Guide to Long-Term Care Insurance”?',
#  '753bdb3a-8a9b-44a1-afb7-7f28a09bf1b8': 'What is the role of the primary payer and secondary payer in covering healthcare costs under Medicare?',
#  'c8f8452e-a467-4ae8-acfb-53897875a208': 'Why might you need to sign up for Medicare Part B if your group health plan is the secondary payer?',
#  '038f1ab5-51aa-41cb-af3c-aff5a1c0b416': 'What should you do if your group health plan coverage ends or if you have other changes to your insurance?',
#  '946f7039-fe0d-41f6-b3be-7343df94030f': 'What types of health care costs can Medigap policies help pay for that Original Medicare does not fully cover?',
#  'd6d99fec-76c8-471e-8bb5-1fe4dc7c6977': 'How are Medigap policies standardized and identified across most states?',
#  '83351e46-e4b2-4cca-9c0c-0464b387a231': 'Why are Medigap Plans C and F no longer available to people new to Medicare on or after January 1, 2020?',
#  '8c42fb77-ab3c-4fc3-a30c-cfb8a0cacef1': 'What does "part-time or intermittent" mean in the context of home health services?',
#  '51af4ed4-6f7d-4e6e-bb2d-697b054e81c4': 'Who must assess you face-to-face before certifying that you need home health services?',
#  '875bd404-e4e0-4305-a85b-f50707c43e9c': 'What type of agency must provide the home health care ordered by a doctor or health care provider?',
#  'e8543727-80b9-4b30-983e-4109d59a45ab': 'What telehealth benefits might Medicare Advantage Plans offer compared to Original Medicare?',
#  '93333123-6c02-4284-9ef5-e0202e478f54': 'How can you find out about telehealth benefits if your Original Medicare provider participates in an Accountable Care Organization (ACO)?',
#  '6977f28e-5852-46e8-9e24-0fa36933f457': 'What types of diagnostic tests does Medicare cover, and what costs are you responsible for?',
#  '5a99657f-e943-4eab-a0a0-f424ec2659f4': 'What types of insulin-related products may Medicare drug coverage (Part D) cover?',
#  '53ef80a8-c843-4bbc-b89b-fde866915abb': 'How much is the cost capped at for a one-month supply of each covered insulin product under Medicare Part D?',
#  'ac1f35b3-569a-4505-b909-ce9bb77500f3': 'How many blood glucose laboratory test screenings does Medicare cover each year for individuals at risk of developing diabetes?',
#  '09d40f13-4f87-4426-bbc3-49a5a09768ad': 'What types of pneumococcal infections does Medicare help prevent with its covered vaccines?',
#  'e3e52904-e397-4c2f-bc03-61c0d0bdc7ea': 'Under what condition do you pay nothing for pneumococcal shots covered by Medicare?',
#  '3c5f6c20-995b-4ee8-b3a8-ae968e7f5785': 'What HIV preventive services does Medicare cover for individuals at increased risk of HIV?',
#  '340504f2-e70f-4821-960c-c6c0410fa159': 'What costs are covered by Medicare for kidney donors during their hospital stay?',
#  'ca1617b6-1fb6-438e-bcc7-60b79f24fc41': 'How long does Medicare coverage, including immunosuppressive drug coverage, last after a successful kidney transplant for someone with ESRD?',
#  'd09afff4-3601-424c-b509-49b9e6ca2ffe': 'Under what conditions does Medicare offer a benefit to help pay for immunosuppressive drugs beyond 36 months after a kidney transplant?',
#  '49d1cb09-838a-4818-bb87-0af7fb37b626': 'What are the income and resource limits to qualify for Extra Help with Medicare drug costs in 2024 for a single person?',
#  'e82e4fb1-5b61-4f14-ae73-58b022562b84': 'How can someone find the contact information for their state’s Medicaid office to apply for Medicare Savings Programs?',
#  '868e5293-70ac-47f9-b9ca-0a31088470f8': 'In which US territories are Medicare Savings Programs not available?',
#  'b6e4f5b4-56ce-4227-86df-c503b0169048': 'What determines the amount you pay for the Part A premium in 2025?',
#  'cfdf332f-d0a4-4991-b07d-842fc2040dab': 'What happens if you don’t buy Part A when you’re first eligible and aren’t eligible for premium-free Part A?',
#  '374ccc9d-fbec-4abf-8495-28b66d6f119e': 'Can you buy Part B without buying Part A if you are eligible?',
#  '14f47680-ebf2-4ffa-ba78-4277c611f92e': 'What is the purpose of the yearly “Wellness” visit?',
#  'befcd58e-e22c-4506-8618-e431e5b9d7c1': 'How often does Medicare cover the “Wellness” visit?',
#  'c049ac8e-8d4e-4b90-b9fe-ba598bb6f2e7': 'What activities or assessments might be included during the “Wellness” visit?',
#  'a7256092-fba0-4324-9a17-c32b35d1e772': 'What is COBRA and how does it interact with Medicare coverage?',
#  '6298f6a1-4d47-40e8-90a5-7e06817f06d7': 'What should you do if you have COBRA with creditable prescription drug coverage and want to enroll in Medicare drug coverage (Part D)?',
#  '28dd3ebb-5323-4e3d-ac8a-d698ba72598f': 'Can you have drug coverage in both a Medigap policy and a separate Medicare drug plan at the same time?',
#  'a686d566-a1c4-4247-a226-1dec499842fd': 'What is Medigap used for in relation to Medicare coverage?',
#  '742cb79b-eec3-4ca0-8980-48d61fabb540': 'Besides Medigap, what other types of coverage can help pay your out-of-pocket costs?',
#  '10d9507d-38f7-451f-a880-fb18ab9beb93': 'Can you buy Medigap to cover your out-of-pocket costs if you already have coverage from an employer, union, or Medicaid?',
#  '4b3b3b8e-e858-4ac5-a547-3a2109cacea4': 'What are guaranteed issue rights in relation to buying a Medigap policy outside of the Open Enrollment Period?',
#  'ed90e66d-f59d-4dc1-8de8-d6badc979795': 'How does delaying Part B enrollment due to group health coverage affect the start of your Medigap Open Enrollment Period?',
#  '76cdafbd-a683-44f0-be61-d2292621925b': 'Why might it be more difficult or expensive for people under 65 to buy a Medigap policy?',
#  '48ddcf88-6a52-45c5-b147-03b5beac7793': 'What determines the amount you pay for services covered under Medicare Part B if you use doctors who accept assignment?',
#  'e473637b-3874-4f02-8645-d263c05a9c76': 'How do out-of-pocket costs differ if you have a Medicare Advantage Plan or other types of insurance compared to Original Medicare?',
#  '8f7b9287-31da-4f5b-8127-d10c1c9cf634': 'Is there a yearly limit on out-of-pocket costs for services covered under Original Medicare Part B?',
#  '3f29f315-cedc-4997-aa3f-f9401e18e0fa': 'What types of services does Original Medicare typically not cover?',
#  'e147f5ba-2484-46c3-801f-0826d7e6af15': 'How do Medicare Advantage plans differ from Original Medicare in terms of prior authorization requirements?',
#  'ced85185-47ba-4661-b741-2b30fde5506f': 'What coverage options are available for medical care received outside the United States under Original Medicare and Medicare Advantage plans?',
#  '283830f3-3ef9-4285-a3ee-cc7b4895279e': 'What costs might apply for Part A-covered services, and how can these costs vary if you have other insurance or a Medicare Advantage Plan?',
#  '00f89b07-b58c-4c82-a732-6424e31b8ab9': 'Under what conditions must you pay for blood received during a hospital stay, and what options do you have to avoid these costs?',
#  'd5c5c6a5-6a6a-4e31-a827-59c6151bee5a': 'What are the requirements to qualify for hospice care under Medicare, and what types of services are covered once you agree to hospice care?',
#  '245f3cd9-f6a2-4a17-ae0c-23bc457a7878': 'What information does the Medicare Summary Notice (MSN) provide to beneficiaries?',
#  'f399169e-09ad-4b0e-bda1-9741cbaa319d': 'How often will you receive the Medicare Summary Notice if you do not sign up for electronic delivery?',
#  'eaabb7f3-fb87-41d7-9ff6-70182e26ca75': 'Where can you find information about how to appeal Medicare’s decision if you disagree with coverage?',
#  'c077b077-bd42-451e-8d55-b99818036e25': 'What types of cognitive symptoms might prompt a Medicare-covered cognitive assessment during a yearly wellness visit?',
#  '92c33417-edb9-4be8-b995-2371e4d125c0': 'What services might a doctor provide during a Medicare-covered visit to review cognitive function and develop a care plan?',
#  '1db045e5-a86d-4e39-b4ee-b84ccb765b5f': 'What colorectal cancer screening tests does Medicare cover to help detect cancer early?',
#  '0876e69c-73fc-41f4-96fa-cbbb32dc957c': 'What types of services are included in Medicare-covered cardiac rehabilitation programs?',
#  '2faf1955-e630-41ac-9625-e3a522fb6f3c': 'Under what conditions does Medicare cover cardiac rehabilitation?',
#  '89712ad5-a9a6-4acb-94a1-fcc76a82a974': 'Does the provider need to accept assignment for Medicare to cover cardiac rehabilitation?',
#  '79731a04-af03-4638-80ab-d2d2edf9aad4': 'What rights do people with Medicare have regarding how they are treated by healthcare providers?',
#  '80df51b8-c1aa-43e4-89e9-abb4420be4da': 'How can Medicare beneficiaries receive information if they need it in a language other than English or in an accessible format?',
#  'db27dc3b-2ff6-4f1b-a8a3-7a54d9ee64b8': 'What options do Medicare beneficiaries have if they disagree with a decision about health care payment or coverage?',
#  '5657647d-9d6e-40d9-b1aa-bb3f5930004d': 'How can you switch Medicare drug coverage plans, and what should you expect after switching?',
#  '2b945977-0451-4a73-8355-ec5fc7c21bb7': 'What are the steps and restrictions involved if you want to drop your Medicare drug plan without joining a new one?',
#  'a9f7cbb8-4bc0-438b-ad5f-2b6077a5234d': 'What important documents should you review each year from your Medicare drug plan, and why are they important?',
#  '0cd7bed5-5bce-43c2-b0c0-910ac5958ead': 'What is a “social determinants of health risk assessment” and when is it provided for free?',
#  '47888f42-0c3c-4867-81df-edd225f46515': 'What cognitive issues does Medicare screen for during the yearly “Wellness” visit, and what happens if impairment is suspected?',
#  '42ee30ad-b6aa-40bd-8a3d-34a2ec12b7f3': 'Are there any costs associated with the yearly “Wellness” visit, and what might cause you to have to pay coinsurance or deductibles?',
#  '07d94b6c-7afb-4a90-bd00-1ce6a2eabd67': 'What are the conditions under which Medicare covers an abdominal aortic aneurysm screening ultrasound?',
#  'da9b1e34-1f5a-4519-9e65-bbd3182759db': 'How many acupuncture visits does Medicare cover for chronic low back pain, and what are the criteria for coverage?',
#  'f8e2e761-bd85-4e29-bbd9-c16b2f632a9a': 'What does Medicare cover regarding advance care planning during the yearly “Wellness” visit?',
#  'fafb9c12-3b89-4f63-a659-55f754f45cee': 'What resources are available to help you find and compare health and drug plans?',
#  '4b6c3422-b7e7-4da3-90c0-0b16c3a04d66': 'How can you get free, personalized health insurance counseling through your State Health Insurance Assistance Program (SHIP)?',
#  'c4a3b9cd-be8c-45a4-8ba9-c3e2e39eec8f': 'What are the benefits of switching to the electronic version of the Medicare handbook?',
#  '39f87f2a-0e87-4957-9baa-34894cd4747b': 'What is a Special Enrollment Period and when might you qualify for it?',
#  '976ed000-1c7b-44ff-bb48-302967e562b4': 'How long do you have to join a Medicare Advantage Plan or Medicare drug plan after signing up for Part A or Part B during a Special Enrollment Period?',
#  'b201044d-4a87-4682-954a-5b79a0afaebe': 'Where can you find more information or get help regarding Special Enrollment Periods and Medicare plans?',
#  'be554bf3-03cd-42da-8ff9-c6ddfb7be1c1': 'What types of speech-language pathology services does Medicare cover, and what costs are associated with these services?',
#  '5339abf9-a983-4890-90bf-e8da8ca31a75': 'How does Medicare cover telehealth services through March 31, 2025, and what changes occur starting April 1, 2025?',
#  '99c0364e-e6ec-4d7a-9e39-0b95f7bfbeba': 'What are some examples of telehealth services that Medicare will cover regardless of the patient’s location after April 1, 2025?',
#  '6580bff4-0be6-4cad-b103-b9d2c53a59dc': 'What are the coverage and cost details for routine EKG/ECG screenings under Medicare?',
#  '3c9a8554-92c3-4d75-a7b6-93877b0f82e7': 'How does Medicare cover emergency department services and what costs might you incur?',
#  '8cda6af3-7105-401f-90a9-a7183a7985f4': 'Who can provide E-visits covered by Medicare, and what are the payment requirements for these services?',
#  '24f6d8fe-ff52-4eca-8ff8-2bac8b79bca8': 'Why are Plans C and F no longer available to people new to Medicare on or after January 1, 2020?',
#  'd1e00879-6c0b-4b4a-b8c6-ee06af2cedc6': 'Who may still be able to buy Plan C or Plan F despite the new restrictions?',
#  '4cef37b5-2d50-49b2-8906-1cdc624eb595': 'What plans can people new to Medicare on or after January 1, 2020, buy instead of Plans C and F, and how do these plans differ?',
#  '341c72fe-7721-4da0-814e-ff983c116770': 'What types of costs does the Qualified Medicare Beneficiary (QMB) program cover, and what protections does it provide to beneficiaries?',
#  '3b2c73e5-13ef-4a85-8c89-176df10fef2c': 'Which Medicare Savings Programs cover only the Part B premium, and how do they differ in eligibility?',
#  '04b6eedc-3aef-4fed-8745-e17826541225': 'What steps should a person in the QMB program take if their provider continues to bill them for Medicare-covered services?',
#  '8580407c-442f-46e4-8b50-65b55b949959': 'When does Medicare pay first if you have retiree health coverage?',
#  '06bfb312-71ad-4701-a6db-3f06bf6b4576': 'How does the size of an employer affect whether Medicare or a group health plan pays first for someone 65 or older?',
#  'aacd6690-ff45-4992-bd56-600aabe5f0e3': 'For how long does a group health plan pay first if you are eligible for Medicare because of End-Stage Renal Disease (ESRD)?',
#  '0db09c16-b150-4c37-b4a5-abb0617a786a': 'What diseases are mentioned that immunization practices aim to protect you from?',
#  '87d0b87b-336c-473f-b7b5-3882850f45c7': 'What should you do if a vaccine shot isn’t on your plan’s drug list?',
#  '06900df3-367d-4252-b46c-678a96ef4a6e': 'Where can you learn more about covered vaccines according to the context?',
#  'ca7a3bdc-346a-4e88-9d6a-9df213749306': 'When can you switch to Original Medicare or change your plan each year?',
#  'f4fbf37c-ca20-4d44-9df5-d75c270f6fe8': 'Where can you compare Medicare plans online?',
#  '99b6b825-2988-4360-a1fd-2678cacad228': 'What might happen if you don’t sign up for Medicare when you’re first eligible?',
#  '8077dc65-e60d-4810-a59f-03a86a0b62a5': 'What are the differences in doctor and hospital choice between Original Medicare and Medicare Advantage plans?',
#  'f9031a59-4bab-4afa-9a58-6a6a7f6051dd': 'How do the out-of-pocket costs and premiums compare between Original Medicare and Medicare Advantage plans?',
#  'c0fb7801-6601-4371-be39-b822cf831b98': 'What are the yearly out-of-pocket limits for Original Medicare versus Medicare Advantage plans?',
#  '24eade74-968e-4f32-82df-b2a4ccb7bd07': 'What options are available if you lost Medicaid but already have Medicare?',
#  'a60473e8-7357-48c3-b104-a0d263ab191e': 'When is the General Enrollment Period for signing up for Medicare Part B?',
#  '0800c7ed-37b6-4d53-a177-fbefbc6397e1': 'What happens to your coverage start date if you sign up during the General Enrollment Period?',
#  '884d50f6-41f2-4099-bb58-fdd798722ae7': 'What pages should you refer to for information about signing up for Part B?',
#  'e1eac21b-83b2-4f05-9fac-13b3c43c6e0f': 'Where can you find more information about Medicaid and check if you qualify?',
#  'a4024763-381d-4bf0-a1e9-c082321fa735': 'What phone number can TTY users call to get assistance related to Medicaid?',
#  'ac693086-9507-48f4-8a82-44b24c5da1b0': 'What percentage of Medicare Part A coinsurance and hospital costs do all Medigap plans cover in 2025?',
#  '1fbd362c-6bc2-4e71-947e-5c81975f1ea2': 'Which Medigap plans cover 100% of the Medicare Part B deductible?',
#  '9e93e676-cd32-4d01-a827-3f3dea78ebdb': 'What is the out-of-pocket limit for Medigap Plan K in 2025?',
#  '1474564e-b6fa-4baa-b80a-f2e6c661322b': 'When can you join, switch, or drop a Medicare drug plan or Medicare Advantage Plan with drug coverage?',
#  '9dc8361b-6d65-4445-9403-c64d0cb89694': 'What should you do before making any changes if you have employer or union health and drug coverage?',
#  'e3050b73-2da1-43d6-a480-f89b7f6d74ae': 'Under what circumstances might you qualify for a Special Enrollment Period to make changes to your Medicare drug plan mid-year?',
#  '9e53d23c-4e43-4289-965d-650aefadfb94': 'What steps can you take if you have concerns about the quality of care from a Medicare provider?',
#  '0d597b35-cd67-499c-8a4e-ef920940e4c5': 'What options do you have if your Medicare health or drug plan decides not to participate in Medicare for the coming year?',
#  'ab854b39-4cc3-4b22-b99d-9e2329c8af1c': 'What is an appeal in the context of Medicare, and when can you file one?',
#  'e69e4c21-be3d-406c-886e-e8b31f10fb36': 'When can you sign up for Medicare Part A and/or Part B if you have group health plan coverage based on current employment?',
#  '25a6eebb-fa61-44d5-b5d6-a9afc7ca1cfc': 'What is the time frame for signing up for Medicare Part A and/or Part B after your employment or coverage ends?',
#  'a3ffdbf2-fd11-43f1-adb6-f1699d492806': 'Under what conditions can you request to delay your Part B start date, and how long can the delay be?',
#  'dc5c9ee3-aab1-435d-9d25-622b116e1221': 'Who is eligible to receive Supplemental Security Income (SSI) payments?',
#  'e9ec259c-9cc1-4fef-8450-14ecd061dea5': 'Can people living in Puerto Rico, the US Virgin Islands, Guam, or American Samoa receive SSI payments?',
#  '8c5e5414-2750-40d3-9237-f5ef1ca60799': 'Where can individuals living in US territories find information about programs to help pay their Medicare costs?',
#  '5b07a56c-2153-40a5-bf69-8d67a8d62445': 'What is the out-of-pocket limit for Plans K and L in 2025?',
#  'dffdc563-f17e-4c78-bfbd-8d41d19e0fe9': 'How much is the deductible amount for high-deductible Plans F and G in 2025 before the policy starts paying?',
#  'dd428487-b024-4ea8-a01e-10b9825b1a62': 'What copayments are required under Plan N for office visits and emergency room visits that do not result in inpatient admission?',
#  '4f76c195-e767-4651-b20f-e6270d188e60': 'Do HMO plans typically cover prescription drugs?',
#  'cdcc2ad8-a5fa-43cf-ae65-030e105993f0': 'Is it necessary to choose a primary care doctor when enrolling in an HMO plan?',
#  '004fb46b-7ffa-42c4-be4c-cae619b2e695': 'Are referrals generally required to see a specialist under an HMO plan?',
#  '3ce0b896-1a95-41a4-84de-cd5a1655f3b2': 'How can you change your address on your Medicare Summary Notice (MSN)?',
#  'bf876796-0282-4cc3-8e00-20be49c71394': 'What protections does the Qualified Medicare Beneficiary (QMB) program provide regarding Medicare Part A and Part B costs?',
#  'f1840ca4-e076-4716-a2d9-22475e560aa1': 'What are the benefits of signing up for electronic Medicare Summary Notices (MSNs)?',
#  '608f1b05-d323-4f83-a6f3-28d02c63fee7': 'What page numbers provide information about outpatient hospital services?',
#  'da5c12ff-e034-4366-8eb7-4aba1058d973': 'Where can you find details about the Medicare Prescription Payment Plan?',
#  '58bc03b3-885f-49d6-9c2a-60231b69478f': 'On which pages are payment options for premiums discussed?',
#  '5cbb60c8-29d4-4bc8-9446-d33320f20c95': 'What deductible still applies to Opioid Treatment Program services for those enrolled in Medicare Part B?',
#  'e27ceb2b-37ee-4232-85d1-4031623f32bd': 'Where can you find a program near you for opioid use disorder treatment services?',
#  'a7a46dc1-3217-4321-92fc-5c1b5569818c': 'What might Medicare Advantage Plans require regarding Opioid Treatment Program services and potential copayments?',
#  'd5fd59f5-8d69-4d38-aad8-c280a9226c92': 'What bariatric surgical procedures does Medicare cover and under what conditions?',
#  '4f5a1844-58b3-478c-9688-2dcf97a296f0': 'What types of services are included in the Psychiatric Collaborative Care Model for behavioral health integration?',
#  '74c0a6cb-2034-4404-b831-24970ff6fb9e': 'How does Medicare handle costs related to blood transfusions and blood processing services?',
#  'cc3383e9-f4c1-49b1-bbe8-88ed7c14cde8': 'Where can you find the phone number for your local State Health Insurance Assistance Program (SHIP)?',
#  'f98adc51-e2a8-47bd-bff6-e2f87d277124': 'When can you sign up for premium-free Medicare Part A if you did not get it automatically?',
#  'c51aa056-3740-47ed-ae76-d14b673bde37': 'During which pages can you find the enrollment periods for signing up for Medicare Part B?',
#  '5ffcf780-d8ac-44d4-9338-3fb64ff5560d': 'How can you get help filing an appeal for your Medicare coverage decision?',
#  'e8aca9f8-0b92-48ab-afd6-7e0a50ae5233': 'What steps should you or your prescriber take to ask for a coverage determination or exception?',
#  '12eb8e4c-efae-41d7-a938-d67a16787140': 'Under what circumstances can your request for an expedited coverage determination be approved?',
#  'cf72bfb2-97dc-4d99-90ce-c58188d83068': 'What are the conditions that qualify a person as "homebound" for Medicare to cover home health services?',
#  '5dd323ec-ee2d-44ce-b1de-bffd92205db5': 'How much do you pay for Medicare-covered durable medical equipment used in home health services?',
#  '4d1ab10d-883a-482c-b82a-64ab3d6930d6': 'What types of services and supplies does Medicare cover for kidney (renal) dialysis for patients with End-Stage Renal Disease (ESRD)?',
#  '659b87c0-3a31-48eb-b03b-6c1fb7573726': 'Can I use out-of-network providers with a PPO Plan, and what are the cost implications?',
#  '19d1e044-504e-425b-85bd-8082e74cdc44': 'Do PPO Plans require you to choose a primary care doctor or get referrals to see specialists?',
#  '2665b123-ea24-4e65-9a45-6366fc1a49bc': 'What must you consider if you want Medicare drug coverage when enrolling in a PPO Plan?',
#  '6382b6d9-855a-401c-8803-0dffc0d88217': 'What costs are associated with getting PrEP medication and related HIV and hepatitis B virus screenings through Medicare Part B-enrolled pharmacies and doctors who accept assignment?',
#  '920a3ebd-f3d8-4841-85a9-e8397c407140': 'How does Medicare support the management of a single, complex chronic condition under principal care management services?',
#  '9838aeb9-0db7-4365-9086-04a530e84f75': 'What preventive prostate cancer screenings does Medicare cover for men over 50, and what are the associated costs?',
#  '4faf324e-c4bb-4de0-b64c-626ce6a94c28': 'What happens if a provider leaves your Medicare Advantage Plan’s network during the year?',
#  'bea3d5c1-da83-4a62-aac9-fbbf32338a69': 'How does your Medicare Advantage Plan assist you if your current provider is leaving the network?',
#  '71f8e4bd-21ca-410a-81d4-c656cc22c9cb': 'What important documents should you review each year if you are enrolled in a Medicare Advantage Plan?',
#  'e5f66ed1-90cd-4e40-bf1e-3ac028182e0b': 'What are some ways to potentially lower the cost of your Medicare Part D drugs?',
#  '81717c05-2d03-40cc-8d3a-96c4bc7ea316': 'How does having a higher income affect the cost of Medicare drug coverage (Part D)?',
#  'c3b95b4a-d90b-4ff6-a119-3264900195e4': 'Who should you contact if you want your Medicare drug premium deducted from your monthly Social Security or Railroad Retirement Board payment?',
#  'eb03288d-ca82-4cf2-a825-aecea30936b1': 'How can you find out if your Medicare Advantage plan covers a specific service, drug, or supply?',
#  '99d8071d-8e7d-41a0-a59b-fa9af7cda4f8': 'What is an "organization determination" and when might you need to request one?',
#  '5ba16734-892d-4d68-8722-f7fe8e519f4c': 'What are the network restrictions for Health Maintenance Organization (HMO) Plans under Medicare Advantage?',
#  '42dee3f8-c510-46c9-b804-b6e1a2994b1b': 'How many kidney disease education sessions does Medicare cover for patients with Stage 4 chronic kidney disease?',
#  'a5802eb5-2aae-47af-8ff0-7bdc3afa286e': 'What percentage of the Medicare-approved amount do you pay per kidney disease education session if provided by a doctor or qualified health care provider?',
#  'd14f1ff9-de1f-4a2b-bba6-64aea2470e6f': 'Does Medicare cover the cost of medically necessary clinical diagnostic laboratory tests, and do patients usually have to pay for these tests?',
#  '3eb0293d-2975-4e86-af7c-e5cde8bd7114': 'How often does Medicare cover Human Papillomavirus (HPV) tests as part of a Pap test for individuals aged 30–65 without HPV symptoms?',
#  'a9036104-fd45-486f-8be7-8030787bd758': 'What are the cost-sharing requirements for chemotherapy covered by Medicare in a doctor’s office or freestanding clinic?',
#  '90f82368-759e-4f5e-b7f9-93d40d3d50b1': 'What services are included in Medicare’s chronic care management for individuals with two or more serious chronic conditions?',
#  '4b88a574-35f8-409f-b7a7-bcecbec82b6b': 'How is the monthly late enrollment penalty for Medicare drug coverage calculated?',
#  '72ddc886-b149-43fe-a73a-e77b60a77600': 'Why did Mrs Martinez have to pay a late enrollment penalty in 2024?',
#  'eaa9e54e-0497-4e73-bd16-4e7f42c7c34f': 'How does the rounding rule affect the calculation of the monthly late enrollment penalty?',
#  'c2f86f40-e27a-4651-9c55-b579b664dd19': 'Why doesn’t COBRA coverage count as employer coverage for a Special Enrollment Period when signing up for Medicare?',
#  '8b8a4c00-1736-4f6e-ad4d-db11512fc1db': 'What are some exceptional circumstances that may allow you to sign up for Medicare during a Special Enrollment Period?',
#  '74cee8df-219d-4a11-81d2-22014fa6b5b8': 'What should you do to avoid paying a penalty when signing up for Medicare after your coverage based on current employment ends?',
#  'f9759cfe-a53e-497a-9785-1f3f6776b27c': 'What types of facilities provide mental health care services covered under Medicare?',
#  '7c0cde78-8304-4df3-b7ff-49ba40544c66': 'How do partial hospitalization and intensive outpatient services differ from regular doctor or therapist office visits?',
#  'e8a1c89f-d2ea-46ad-89a7-83e99aa80c30': 'What are the typical out-of-pocket costs for mental health care services under Medicare Part B?',
#  '32928bbd-3f13-4f65-b310-08761c4428a1': 'What pages provide the most detailed information about End-Stage Renal Disease (ESRD)?',
#  '898abae1-b23e-4bdc-8b54-e3f69f31e78f': 'On which pages can you find information about Medicare drug coverage (Part D)?',
#  'aefeb854-785d-41ae-af87-449a858ad74f': 'Where in the index can you find details about home health care/services?',
#  '381b777d-92a3-43d4-aee6-b85797913d66': 'Where can I call to get more information about special rights to buy a Medigap policy?',
#  'bcb141f1-edad-4667-81e7-af40fbde49ee': 'What website can I visit to find Medigap policies and pricing in my area?',
#  '653429d3-32ff-48bf-9de2-6c066a1b4e1a': 'Which publication can I review to learn more about choosing a Medigap policy?',
#  '7c9807c8-6c1b-43c3-a0f8-2e3ea80fa457': 'What are the three ways to avoid paying a late enrollment penalty for Medicare drug coverage (Part D)?',
#  'ecf55cdf-286a-4abf-a2ec-b0f46c0ff26c': 'How is the late enrollment penalty for Medicare drug coverage calculated?',
#  '9f2fa07f-dda1-4a35-9cff-c465e9c124ec': 'Why is it important to keep records of your previous creditable prescription drug coverage when enrolling in Medicare drug coverage?',
#  '2ba21ea4-3a03-4c96-a2a9-fb5f9614d5a9': 'What are the eligibility criteria for Medicare to cover lung cancer screening tests with low dose computed tomography?',
#  'c740b1fd-6ecf-47ad-b3cb-86141bce6051': 'How much do you have to pay for lymphedema compression treatment items under Medicare, and what deductible applies?',
#  '582ed71c-3ac9-4f39-8a0e-5d27a08cdaba': 'Under what conditions does Medicare cover medical nutrition therapy services?',
#  '11723b38-5f57-4fdc-ba50-36860dbbad32': 'What types of routine medical services are not covered by Original Medicare?',
#  'ccce6d50-5f87-4457-a160-4c3e0bbf1b16': 'Does Original Medicare cover most dental care services, and are there any exceptions?',
#  '25757f44-7df9-48de-9e14-c859d3bdb58a': 'What types of long-term care services are not paid for by Medicare and Medicare Supplement Insurance?',
#  '13505b30-d78a-4168-9b84-fa476e0f4403': 'What topics related to Medicare are covered between pages 25 and 90?',
#  'edea2f6c-09df-45b5-938a-fe2c03344904': 'On which pages can information about Medicaid be found?',
#  '638dbb61-2804-484c-b9da-a9077c17504d': 'Where can details about Medicare Supplement Insurance (Medigap) be located?',
#  'cda460f6-a8b5-4966-8d4e-9c2450720d60': 'What could happen if you don’t pay the extra amount for your Medicare Part D coverage?',
#  '7f203766-7db6-49ab-8e53-4214d2d347c4': 'How are Part D IRMAA payments handled if your employer or another third party pays your plan premiums?',
#  'b5996518-c7aa-4d9c-ad15-fa919a5bba14': 'What is a yearly deductible in a Medicare Part D plan, and how does it affect drug coverage?',
#  '57c356de-7a2c-493b-91d8-2479150eb31c': 'What are the two main ways to get Medicare coverage?',
#  'a1201fd7-22a8-4001-a678-8247a642251a': 'What types of coverage are included in Original Medicare?',
#  '5f19ce1c-6b52-4b22-a936-86525d3cb35d': 'How does Medicare Advantage differ from Original Medicare in terms of provider networks and coverage?',
#  'c1fb1c1c-5234-4b5a-8642-04d67a59dc35': 'What types of fees does Medicare cover for surgical procedures performed in ambulatory surgical centers?',
#  'c5ce41cc-8904-4fdc-a7c0-b1aa4fe69c23': 'How much does a patient typically pay for covered services at an ambulatory surgical center under Medicare Part B?',
#  '6ed29d6c-dfbd-460c-a2ef-f6a3aa74509d': 'Are patients responsible for any fees if Medicare does not cover a procedure performed at an ambulatory surgical center?',
#  '3f47aeac-663a-4a14-bbee-f99aade5eb21': 'What are the eligibility requirements to join a Medicare Advantage Plan?',
#  '52cfaf24-73e0-4ae2-afb1-657cabbaf03c': 'Can someone with End-Stage Renal Disease (ESRD) join a Medicare Advantage Plan, and what happens to Medicare benefits after a kidney transplant?',
#  '1e6a7eef-acfc-4ccd-a4be-1f80bd458d69': 'Do all Medicare Advantage Plans include Medicare drug coverage (Part D), and what options are available if a plan does not include drug coverage?',
#  '5c466bfd-f674-4c61-a0a9-38434bc5126f': 'What are the benefits of qualifying for Extra Help when joining a Medicare drug plan or Medicare Advantage Plan with drug coverage?',
#  '6cc36eda-1577-4305-b679-c509f75dfbf3': 'In which US territories is Extra Help not available, and what should residents in those areas do if they need assistance with health and drug costs?',
#  'fba9ef59-7e74-4917-b629-e55b0c71b44e': 'How can someone qualify automatically for Extra Help, and what should they expect to receive from Medicare if they do?',
#  '6c62d37c-f5ea-474f-8736-9f77ff14cc29': 'How often does Medicare cover a CT colonography screening test for individuals who are 45 or older and at high risk for colorectal cancer?',
#  '9b7443ef-3e47-4858-8660-c70cf1bf8114': 'What is the coverage frequency for screening colonoscopies under Medicare for individuals who are not at high risk?',
#  'b52abbeb-50bf-4113-bf90-e01de52ddd70': 'Does Medicare cover a follow-up colonoscopy if a non-invasive stool-based screening test returns a positive result?',
#  'b5bcb779-b3f2-4e89-b4c2-40c6862c0ccf': 'What should you do if your Medigap insurance company needs to remove drug coverage or adjust your premiums?',
#  '10c6e227-105a-424f-a182-472181c1d9d7': 'How does the Federal Employee Health Benefits Program (FEHB) interact with Medicare drug coverage (Part D)?',
#  'c1c50885-ed2e-4d47-a8ac-31ee50d62659': 'Where can eligible US Postal Service employees and retirees find information about their health benefits coverage?',
#  'cc836777-a911-4757-b997-4e064e22293d': 'What might happen if you go to a doctor or health care provider that is not in your plan’s network for non-emergency care?',
# ...
#  '7eced837-65b2-4827-b1f4-a43008f80d53': 'What are the daily costs for skilled nursing care under Medicare during days 21 to 100 in each benefit period of 2025?',
#  'e7962be7-ed6c-4133-be8a-e3d37256becc': 'Under what circumstances can you appeal a discharge from skilled nursing care or therapy?',
#  '9e9bf20b-0082-4576-bbfc-76899d2953c6': 'What types of services does Medicare Part B help cover?',
#  'ebaafbb5-094b-4067-94cc-9a042e573790': 'What is the standard Part B premium amount in 2025?',
#  '11fd7e44-f373-4cb6-b392-44389c9c26f8': 'How does Medicare determine if you have to pay the Income Related Monthly Adjustment Amount (IRMAA)?',
#  'd8ffbbb4-e05f-4b61-8b6a-203ec75d8894': 'What happens if you don’t sign up for Part B when you’re first eligible?',
#  '6b59a9c2-4a71-4a70-bb20-daece54e97a7': 'What are copayments and coinsurance in Medicare Part D drug coverage, and how can the amounts you pay vary throughout the year?',
#  '90d42d59-3b70-48e1-96f1-21f5a09bcea3': 'What is the yearly out-of-pocket limit on drug costs for Medicare Part D in 2025, and what happens once you reach this limit?',
#  '3f64e519-c0a0-49b8-b7f8-0f336bbca604': 'How does the Medicare Prescription Payment Plan help manage out-of-pocket drug costs, and does it reduce the overall amount you pay for drugs?',
#  '7f03b640-886e-4f80-8403-85f3b1e4555e': 'What is an at-risk determination under the Drug Management Program, and which types of drugs does it typically involve?',
#  '4b9173b4-f115-40c9-bd8b-00af14cf89fa': 'Under what circumstances can you appeal a claim denial related to an open accident record?',
#  'd5f87dd3-3484-4d19-9e38-9a96693418ff': 'What steps should you take if your hospital status is changed from inpatient to outpatient and you want to appeal this decision?',
#  '7ab73621-ed92-452e-8096-e42eae397440': 'What should you do if you want to change your Medicare plan after coverage begins?',
#  '8a014da8-706b-44e3-ac35-7ab431837878': 'How can you find out if your Medicare plan covers the drugs you use and the pharmacies you want?',
#  'aa517c56-faf8-4c16-89ca-2b40cb8a9631': 'What are the typical drug costs for people who qualify for Extra Help under Medicare?',
#  '20c6cc6b-2970-4909-acd0-4f129c1d22b9': 'What is the purpose of the State Health Insurance Assistance Program (SHIP) and where can you find the phone number for your local SHIP?',
#  '51322a11-cfb2-4b40-bc6a-ca49439acdb1': 'Who is eligible for Pharmaceutical Assistance Programs and where can you find more information about these programs?',
#  '4a909bfa-c3f9-4827-baba-0596db74fd33': 'What is the Program of All-inclusive Care for the Elderly (PACE) and what type of care does it provide?',
#  'eab5a33f-3635-468a-bfb9-5894c331fd8f': 'What types of diabetes self-management training does Medicare cover, and what are the cost-sharing requirements for these services?',
#  '48c645ef-1d70-4f8d-b9dd-02cb311b6e05': 'Which health care providers’ services are covered by Medicare Part B, and what costs might a patient expect to pay for these services?',
#  '075eb180-d47c-4e7d-bec2-17aa4197ca02': 'What kinds of outpatient prescription drugs are covered under Medicare Part B?',
#  '10dbab83-c3f9-4da8-9c39-899301718475': 'What are the different parts of Medicare as outlined in the contents?',
#  '31eac9cf-de50-4e59-94ca-b00f4f50ffcc': 'Which sections of the document provide information about Medicare Advantage Plans and Medicare Supplement Insurance (Medigap)?',
#  '58d1683e-a7e9-4df6-95bf-857f806c7bf2': 'What symbols are used in the document to help understand Medicare coverage, and what does each symbol represent?',
#  '9dd22c08-71f5-45fd-92d8-8260a31f57d1': 'How long must a doctor or health care provider commit to opting out of Medicare once they choose to do so?',
#  '2ce4080b-3241-45a0-b0ec-a35558befa1a': 'Where can you check if a provider has opted out of Medicare to know if you need to pay out of pocket?',
#  'd8d05aa8-1bd8-4e76-a3b2-0137ee976171': 'What resource can you contact for free help regarding Medicare options and medical equipment suppliers?',
#  '9f34e690-c4b7-4b67-9c71-9ca1278a2bee': 'What types of care are included in the current and future Medicare models, demonstrations, and pilot initiatives?',
#  '682df37f-1e05-495f-9d04-5eb98b34b6bd': 'How can you find out if your doctor participates in these Medicare programs and what it means for your care?',
#  '4d5ccb0c-9781-40fa-95a4-be1a8298bd00': 'Where can you call or look to learn more about the current Medicare models, demonstrations, and pilot initiatives?',
#  '68ef17e5-13ac-458d-ba2b-799a309d3f5d': 'What are the potential consequences of dropping your Medicare Supplement Insurance (Medigap) policy to join a Medicare Advantage Plan?',
#  '0198d7e5-f481-42e9-83f2-46a1deac7c8d': 'Under what circumstances can you drop or change your Medicare Advantage Plan during the year?',
#  '5c81933d-67d5-494c-a1c2-a7a34437c7f6': 'What are some key features and rules of Medicare Cost Plans compared to Original Medicare?',
#  '310792c1-6a53-40d8-8e99-77a57d4d3496': 'What are the rules regarding getting non-emergency health care outside the network in Medicare Advantage Plans?',
#  '2701a4da-ea39-4799-a753-b6940edb9520': 'How does a Medical Savings Account (MSA) Plan work in terms of using deposited money and meeting deductibles?',
#  '03e04319-631d-48f1-ac83-f0250be2afea': 'Do Medicare MSA Plans cover prescription drugs, and what must you do if you want drug coverage?',
#  '286fd731-1892-4cc9-8fb0-4adc57a2b809': 'What options are available for veterans to receive drug coverage through the US Department of Veterans Affairs (VA) program?',
#  '6cc99eea-4a6f-474f-abba-7522b81d91ed': 'How does CHAMPVA coordinate with Medicare drug plans, and what are the benefits of using the Meds by Mail program?',
#  '1671b8d4-4a88-4c4d-8f32-504f8c75764a': 'What are the requirements for TRICARE beneficiaries to maintain their drug benefits, and how do TRICARE and Medicare drug plans coordinate payments?',
#  'c2f48d81-7b95-4e7d-8246-6651a251e935': 'What are the general requirements to buy Medicare Supplement Insurance (Medigap)?',
#  'b9ef3300-51ac-47c5-bd83-f569b0153d18': 'How does Medicare SELECT differ from a standard Medigap policy?',
#  '932d4fc4-c8aa-40ef-83c4-91b70c504fb7': 'When is the best time to buy a Medigap policy and why?',
#  '1fe82d01-978e-44bb-95b4-00cd42addc58': 'What percentage of the Medicare-approved amount do you generally pay for doctors’ services in a hospital outpatient setting?',
#  '5d854cac-a462-4f00-8143-6fc0bcbcbb1c': 'How does the copayment for hospital outpatient services compare to the Part A hospital stay deductible?',
#  '5dcb0176-987c-464d-8bdc-467f0afe967a': 'Under what conditions does Medicare cover physical therapy services, and what costs are the patient responsible for?',
#  '864900ff-e85c-4630-90ae-b56d6e5b4c3a': 'What conditions must be met for Medicare to continue covering CPAP devices and accessories after the initial 3-month trial period?',
#  '8c484101-de9a-41e2-bfdb-3d63a28c782d': 'How much do you pay for the rental and purchase of CPAP machines and related supplies under Medicare Part B?',
#  '00f759e0-4edc-40c8-8476-ab15d8034819': 'After how many months of uninterrupted rental do you own the CPAP machine covered by Medicare?',
#  'c8c86d67-e24f-4148-bca0-74970484a545': 'What should you do with your Marketplace coverage when you become eligible for Medicare to avoid overlapping coverage?',
#  '4c3f6f96-e488-4599-ac68-c1fbd30a1b82': 'Why is it important to stop making Health Savings Account (HSA) contributions before your Medicare Part A coverage begins?',
#  '02b92242-a886-4d76-bc68-c39e1e4f818f': 'What could happen if you continue to receive help paying for your Marketplace plan premiums after becoming eligible for premium-free Part A?',
#  '56a1e205-3735-4740-a4a1-de4921706f3f': 'What should you consider if you or your spouse have employer or union health coverage when deciding whether to sign up for Medicare Part B?',
#  'cd78a850-0d03-40dd-81ed-219dfec58cc6': 'How does having TRICARE coverage affect the requirement to sign up for Medicare Part A and Part B?',
#  'e45da70c-6c4d-4f3d-9508-aae011ebd85c': 'What options are available for people with Medicaid who do not have Medicare Part B regarding payment of premiums?',
#  '03ad4df2-4bc4-423a-b106-c2851a62975a': 'How can you opt out of a Medicare drug plan if you want to keep your employer or union coverage?',
#  '8c7a8f43-3b20-4002-bcc0-8a187508ccb5': 'What should you do before getting Medicare drug coverage if you have employer or union coverage?',
#  'eb005301-a24d-4060-b840-ec5e977a14a9': 'Where can you apply for Extra Help and begin the application process for a Medicare Savings Program (MSP)?',
#  'c79e2a31-eea2-4e0c-8288-6d0be82e815d': 'How is Mrs Martinez’s monthly late enrollment penalty for 2025 calculated and what is the final amount she must pay each month?',
#  '0dc70c33-d275-466c-be69-aaff37712f6c': 'What steps can a Medicare beneficiary take if they disagree with their late enrollment penalty?',
#  '18bf6f4a-46d0-46b6-94e0-cbb27030147f': 'What types of drugs must Medicare plans cover, and why is it important to review a plan’s formulary before joining?',
#  '2d16f293-ef74-4c67-9634-d425b578faa1': 'How can the cost of your copayment or coinsurance change when a generic or biosimilar version of a drug becomes available?',
#  'f07d7d4c-9b29-477c-ac86-4f854e80bac1': 'What types of drugs does Medicare Part B cover, and how does this differ from Medicare Part D coverage?',
#  'a1561763-77d3-49a5-8fc4-7f89ebdee7b5': 'What options do you have if your prescribed drug is placed in a higher tier on your Medicare Part D formulary?',
#  'f5d905ed-a39c-4731-b07b-3ebca11c26dc': 'What types of counseling are provided as part of hospice care?',
#  '4d4f2246-4ea4-42c5-b163-abcdff5a0358': 'Where is Medicare-certified hospice care usually given?',
#  '15d35d31-354f-4f6a-9599-9857a97eb05d': 'Under what conditions will Medicare pay for room and board in a facility during hospice care?',
#  '1e85dc72-e2c0-4e74-8015-b6ad7ae34248': 'What types of medications are covered for use in the home according to the context?',
#  '6276b3e8-b819-4e62-8265-6a84e69667d7': 'Under what circumstances are certain drugs received in a hospital outpatient setting covered?',
#  '60b84e75-8822-4e37-a977-8b05ca310880': 'When do you have to pay 100% for most drugs, based on the information provided?',
#  '982dbfd6-4b14-4a02-9b68-c1f2a8c0d948': 'What steps should you take to file an appeal if you have Original Medicare?',
#  '96769384-05ff-4e88-ba1e-d3c33a65673b': 'What information must you include when sending your appeal to the Medicare Administrative Contractor?',
#  '47dc28ed-4563-4923-b873-427ba74676d6': 'What can you do if you miss the deadline for filing a Medicare appeal?',
#  '4be57168-4557-4ab7-8f83-9f3038c8fab4': 'What should you do if you find mistakes in your monthly “Explanation of Benefits” notice from your Medicare drug plan?',
#  '6e2b3f64-c4de-44ca-831e-6f218469f008': 'How can prior authorization affect your ability to fill a prescription under Medicare drug coverage?',
#  '97888ae3-6797-48c2-b7fb-51a3cd82a9c3': 'What types of safety checks are performed by your plan and pharmacy before filling opioid pain medication prescriptions?',
#  'a13bba0c-b2e5-40f9-b4f4-66f1f133c991': 'How many face-to-face counseling visits does Medicare cover in a 12-month period for tobacco use prevention, and what is the cost to the patient if the provider accepts assignment?',
#  'cdfc69b9-d9c3-46ea-b803-74c370a4974c': 'What types of COVID-19 related services and items does Medicare cover, and what should you bring when getting a COVID-19 vaccine to ensure proper billing?',
#  '828cda19-b342-493a-97c5-2c0ae5968288': 'Under what conditions can a Medicare beneficiary receive monoclonal antibody treatments for COVID-19, and what is the purpose of these treatments?',
#  '37541db0-aa33-423b-b3e3-11c518338d78': 'What is the Medicare Prescription Payment Plan and how can you participate in it?',
#  '05e9a69e-03d5-4979-9889-1c9a50ee4d85': 'Who might find the Medicare Prescription Payment Plan not to be the best payment option?',
#  'c2abb490-7ac2-41de-9ced-be93ec48ac81': 'What causes the Medicare drug coverage (Part D) late enrollment penalty and how long do you have to pay it?',
#  'eb09da8d-ea0e-426e-915e-3278e81b5b25': 'What types of care does Medicare cover under inpatient respite care, and how long can you stay each time you receive this care?',
#  '1cfc0c2d-37dc-40f8-b294-c300e7643cd2': 'What costs are associated with hospice care under Medicare, including outpatient drugs and inpatient respite care?',
#  'abe4e431-b832-4daa-92eb-a79b4d424e97': 'What inpatient hospital services and supplies does Medicare cover, and what items or services are not included?',
#  '7b7cdc93-28f7-493c-bec2-92681dd0df95': 'What might happen if you decide not to get Medicare drug coverage when you’re first eligible and your other drug coverage isn’t creditable?',
#  'b34417c4-62b8-41ca-936f-d70b490403ca': 'Why is it important to talk to your employer, union, or benefits administrator before joining a Medicare Advantage Plan?',
#  'cccff817-c1cb-43b1-8a96-fa4e2e7e6b36': 'Can you be enrolled in more than one Medicare Advantage Plan at the same time?',
#  'c541781a-f4a5-4ffd-9abc-3fa578dbb877': 'Can you use any Medicare-approved doctor or hospital with a Private Fee-for-Service (PFFS) Plan?',
#  '2ae6544d-addc-4a5e-9823-fcd9fa1c66d2': 'Do Private Fee-for-Service (PFFS) Plans always include prescription drug coverage?',
#  '3698c651-62ba-4393-a942-fecdaeb663f6': 'Is it necessary to choose a primary care doctor or get a referral to see a specialist in a PFFS Plan?',
#  '2a25a30a-1196-404e-99b3-cf4ce7b78796': 'What is the yearly out-of-pocket drug cost cap for Medicare Part D in 2025, and what happens once you reach this cap?',
#  'db643e39-6926-4136-9625-8b7aae973be7': 'How does Medicare support mental health care and what role does the yearly “Wellness” visit play in managing mental health?',
#  '7f48bbc8-2c47-4461-bc03-0d1f50d2a2d6': 'What are the changes to telehealth coverage starting April 1, 2025, and which telehealth services can still be accessed from home regardless of location?',
#  '1f96ff9e-43ee-43d6-9b55-548149fd248e': 'Is it legal to buy a Medigap policy if you are currently enrolled in a Medicare Advantage Plan and not switching back to Original Medicare?',
#  '6af5979e-ab1c-4201-8c14-8c818d8c8da7': 'What happens if you drop your Medigap policy to join a Medicare Advantage Plan for the first time and later want to get your Medigap policy back?',
#  '89398fe3-cd1d-4bbc-ad63-bc3577458e5b': 'What options do you have if you joined a Medicare Advantage Plan when you were first eligible for Medicare Part A at 65 and decide to switch back to Original Medicare within the first year?',
#  '2c1811ce-c04b-40a4-9184-dc4f95d25d33': 'What pages provide information about Skilled Nursing Facility (SNF) care?',
#  'b7a4fbf9-7012-49bf-a078-99e86c52bdba': 'Where can you find details about the State Health Insurance Assistance Program (SHIP)?',
#  '619ba173-1060-4076-b784-38e0b5bfdfe7': 'On which pages is information about Special Enrollment Periods for Part A and Part B available?',
#  'f0e14c4d-2556-4c07-9700-b91ccc6d54c7': 'How can I find out if I qualify for Medicaid in my state?',
#  '096e68c9-794a-489b-9b1e-454aefb3c962': 'What are Medicare-Medicaid Plans and how can I check if they are available in my area?',
#  '4ec4ae90-0f7d-4460-b82f-7e0c046fb6ee': 'Where can I get information about State Pharmaceutical Assistance Programs in my state?',
#  '80c88ad9-9fe8-444f-9f83-af7887e38740': 'What percentage of the Medicare-approved amount do you pay for corrective lenses after cataract surgery with an intraocular lens?',
#  'b522bb24-54b4-4554-805b-1b6266e9e479': 'Are there any deductibles when receiving services at Federally Qualified Health Centers, and what costs might you typically pay?',
#  '30802178-df5e-4aee-a081-e2dcc14765f7': 'Under what condition do you pay nothing for a seasonal flu shot covered by Medicare?'}

# %%
val_questions, val_relevant_contexts = await create_questions(val_split_documents, 10)
# Out:
# Processing documents: 100%|██████████| 20/20 [00:05<00:00,  3.78it/s]

# %%
test_questions, test_relevant_contexts = await create_questions(test_split_documents, 10)
# Out:
# Processing documents: 100%|██████████| 20/20 [00:05<00:00,  3.66it/s]

# %%
import json

training_corpus = {train_item.metadata["id"] : train_item.page_content for train_item in training_split_documents}

train_dataset = {
    "questions" : training_questions,
    "relevant_contexts" : training_relevant_contexts,
    "corpus" : training_corpus
}

with open("training_dataset.jsonl", "w") as f:
  json.dump(train_dataset, f)

# %%
val_corpus = {val_item.metadata["id"] : val_item.page_content for val_item in val_split_documents}

val_dataset = {
    "questions" : val_questions,
    "relevant_contexts" : val_relevant_contexts,
    "corpus" : val_corpus
}

with open("val_dataset.jsonl", "w") as f:
  json.dump(val_dataset, f)

# %%
train_corpus = {test_item.metadata["id"] : test_item.page_content for test_item in test_split_documents}

test_dataset = {
    "questions" : test_questions,
    "relevant_contexts" : test_relevant_contexts,
    "corpus" : train_corpus
}

with open("test_dataset.jsonl", "w") as f:
  json.dump(test_dataset, f)
